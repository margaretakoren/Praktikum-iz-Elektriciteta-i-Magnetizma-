# %% [markdown]
# # Zadatak 1 df

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages


U1 = [2, 4, 6.4, 8.4, 10.8, 13]
U2 = [8.2, 17, 25, 33.4, 42, 60]


df = pd.DataFrame({
    "U1 (V)": U1,
    "U2 (V)": U2})


df["U2/U1"] = df["U2 (V)"] / df["U1 (V)"]

print(df)

fig, ax = plt.subplots(figsize=(8, 3))
ax.axis("off")
table = ax.table(
    cellText=df.round(3).values,
    colLabels=df.columns,
    loc="center")
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)

plt.savefig("1_tablica.pdf", bbox_inches="tight")
plt.close()
# Out:
#    U1 (V)  U2 (V)     U2/U1
# 0     2.0     8.2  4.100000
# 1     4.0    17.0  4.250000
# 2     6.4    25.0  3.906250
# 3     8.4    33.4  3.976190
# 4    10.8    42.0  3.888889
# 5    13.0    60.0  4.615385

# %% [markdown]
# # Zadatak 2 df

# %%
U1_2 = [1.8, 4.0, 6.4, 8.8, 11.0, 13.0, 16.0]
U2_2 = [4.0, 8.2, 13.0, 17.0, 21.0, 25.0, 30.0]




df1 = pd.DataFrame({
    "U1 (V)": U1_2,
    "U2 (V)": U2_2})


df1["U2/U1"] = df1["U2 (V)"] / df1["U1 (V)"]

print(df1)

fig, ax = plt.subplots(figsize=(8, 3))
ax.axis("off")
table = ax.table(
    cellText=df1.round(3).values,
    colLabels=df1.columns,
    loc="center")
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)

plt.savefig("2_tablica.pdf", bbox_inches="tight")
plt.close()
# Out:
#    U1 (V)  U2 (V)     U2/U1
# 0     1.8     4.0  2.222222
# 1     4.0     8.2  2.050000
# 2     6.4    13.0  2.031250
# 3     8.8    17.0  1.931818
# 4    11.0    21.0  1.909091
# 5    13.0    25.0  1.923077
# 6    16.0    30.0  1.875000

# %% [markdown]
# # Zadatak 3 df

# %%
n2 = np.array([600, 900, 1200], dtype=float)
U2 = np.array([13, 19, 25], dtype=float)
U1 = np.array([6.4, 6.4, 6.4], dtype=float)

df = pd.DataFrame({
    "n2": n2,
    "U2 (V)": U2,
    "U1 (V)": U1})

print(df.round(3))

fig, ax = plt.subplots()
ax.axis('off')

table = ax.table(
    cellText=np.round(df.values, 3),
    colLabels=df.columns,
    loc='center')

table.scale(1, 2)

pdf = PdfPages("3_tablica.pdf")
pdf.savefig(fig, bbox_inches='tight')
pdf.close()
plt.close()
# Out:
#        n2  U2 (V)  U1 (V)
# 0   600.0    13.0     6.4
# 1   900.0    19.0     6.4
# 2  1200.0    25.0     6.4
